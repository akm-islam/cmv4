# %%
import pandas as pd
from glob import glob

# %%
files=glob("*.csv")

# %%
files
# Out:
# ['April.csv', 'March.csv', 'May.csv']

# %%
for file in files:
    df=pd.read_csv(file)
    df.rename(columns={"Topic":"topic_number"},inplace=True)
    df.to_csv(file,index=None)

# %%
df
# Out:
#                                                raw_tweet  month       label  \
# 0      Could it be the incubation period might be sho...  March      Expert
# 1      @mjd1735 I agree with this. Trying to balance ...  March      Expert
# 2      “preppers do not see crises such as the corona...  March      Expert
# 3      @Caryopter @Sydney_C_Jones @CNNnewsroom @markb...  March      Expert
# 4      @cstewartb @dr_michaelmarks @David_Simons_UK @...  March      Expert
# ...                                                  ...    ...         ...
# 41805  b'The sooner people realise the UK Government ...    May  Non Expert
# 41806  b'[ON AIR] In partnership with @ONECampaign, #...    May  Non Expert
# 41807  b'Zhejiang Da Xue Xue Bao Yi Xue Ban. Clinical...    May  Non Expert
# 41808  b"We've been busy continuing to fill our #COVI...    May  Non Expert
# 41809  b'After many Bad NEWS, Finally a good NEWS, A ...    May  Non Expert
#
# ...
